# %% [markdown]
# # Mid Hackathon Submission: (Algorithm: XGBoost, Naive Bayes, Logistic Regression)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
# importing dataset

df_train_full = pd.read_csv('./Train_data.csv')
df_test_full = pd.read_csv('./Test_data.csv')

# %%
# Flooring GP column (games played) as instructed in contest

df_train_full.GP = np.floor(df_train_full.GP) 
df_test_full.GP = np.floor(df_test_full.GP)

df_train_full
# Out:
#         GP   MIN   PTS  FGM   FGA   FG%  3P Made  3PA   3P%  FTM  FTA    FT%  \
# 0     59.0  12.8   3.4  1.3   2.6  51.0      0.2  0.3  50.0  0.7  0.8   78.0
# 1     31.0  10.7   3.4  1.2   3.3  35.3      0.5  2.1  25.8  0.5  0.9   55.2
# 2     48.0   9.3   4.5  1.7   3.4  49.7      0.0  0.1   0.0  1.2  1.9   61.5
# 3     80.0  27.7  11.2  3.5   9.4  37.4      1.3  4.1  32.9  2.8  3.3   85.0
# 4     58.0  18.4   5.8  1.9   5.3  36.7      0.0  0.1  25.0  1.9  3.1   61.7
# ...    ...   ...   ...  ...   ...   ...      ...  ...   ...  ...  ...    ...
# 1096  49.0   8.3   4.5  1.8   3.9  46.6      0.0  0.1   0.0  0.8  1.2   70.2
# 1097  35.0   5.5   1.5  0.5   1.4  36.0      0.4  1.1  33.3  0.1  0.1  100.0
# 1098  65.0  13.2   5.0  2.0   5.0  41.3      0.1  0.3  35.0  0.8  1.0   76.9
# 1099  55.0  14.9   4.1  1.7   4.1  41.7      0.1  0.1  37.5  0.6  0.8   76.1
# 1100  55.0  25.3  14.0  5.2  11.3  46.3      0.1  0.5  18.5  3.4  3.8   89.6
#
#       OREB  DREB  REB  AST  STL  BLK  TOV  Target
# 0      1.1   2.3  3.3  0.5  0.3  0.4  0.5       1
# 1      0.3   1.1  1.4  0.4  0.3  0.1  0.2       0
# 2      0.4   0.8  1.2  0.8  0.5  0.4  1.0       0
# 3      0.8   1.6  2.4  3.9  1.3  0.1  2.2       1
# 4      0.5   0.7  1.2  1.9  1.1  0.2  1.7       0
# ...    ...   ...  ...  ...  ...  ...  ...     ...
# 1096   0.6   0.7  1.3  0.5  0.3  0.3  0.6       1
# 1097   0.1   0.6  0.7  0.2  0.1  0.0  0.1       1
# 1098   0.6   1.0  1.6  1.1  0.7  0.3  0.8       0
# 1099   0.5   1.0  1.5  1.5  0.7  0.2  0.8       0
# 1100   0.8   1.3  2.1  1.9  1.3  0.4  1.4       1
#
# [1101 rows x 20 columns]

# %%
df_train_full.describe()
# Out:
#                 GP          MIN          PTS          FGM          FGA  \
# count  1101.000000  1101.000000  1101.000000  1101.000000  1101.000000
# mean     58.915531    16.928284     6.502344     2.511125     5.645747
# std      17.264655     8.034209     4.163856     1.611502     3.422292
# min      11.000000     3.100000     1.100000     0.400000     1.000000
# 25%      46.000000    10.492268     3.587756     1.400000     3.200000
# 50%      59.000000    15.386486     5.200000     2.000000     4.600000
# 75%      76.000000    21.830403     8.300000     3.200000     6.900000
# max      82.000000    40.900000    24.300000     9.000000    18.900000
#
#                FG%      3P Made          3PA          3P%          FTM  \
# count  1101.000000  1101.000000  1101.000000  1101.000000  1101.000000
# mean     43.912555     0.241959     0.767455    19.050425     1.241914
# std       6.106910     0.363008     1.017214    15.513640     0.937585
# min      25.000000     0.000000     0.000000     0.000000     0.000000
# 25%      40.000000     0.000000     0.000000     0.000000     0.600000
# 50%      43.652785     0.100000     0.300000    22.600000     1.000000
# 75%      47.700000     0.400000     1.195634    32.300000     1.600000
# max      73.700000     2.300000     6.500000   100.000000     7.500000
#
#                FTA          FT%         OREB         DREB          REB  \
# count  1101.000000  1101.000000  1101.000000  1101.000000  1101.000000
# mean      1.741848    70.495847     0.958240     1.937014     2.891927
# std       1.272047    10.381068     0.771344     1.342627     2.039694
# min       0.000000     0.000000     0.000000     0.200000     0.300000
# 25%       0.900000    64.900000     0.400000     1.000000     1.400000
# 50%       1.400000    71.502462     0.700000     1.600000     2.273596
# 75%       2.200000    77.436718     1.300000     2.500000     3.700000
# max      10.200000   100.000000     5.300000     9.600000    13.900000
#
#                AST          STL          BLK          TOV       Target
# count  1101.000000  1101.000000  1101.000000  1101.000000  1101.000000
# mean      1.472706     0.589403     0.344204     1.150499     0.499546
# std       1.376592     0.386147     0.418840     0.687706     0.500227
# min       0.000000     0.000000     0.000000     0.100000     0.000000
# 25%       0.600000     0.300000     0.100000     0.700000     0.000000
# 50%       1.041951     0.500000     0.200000     0.988945     0.000000
# 75%       1.900000     0.800000     0.400000     1.400000     1.000000
# max      10.600000     2.500000     3.900000     4.200000     1.000000

# %%
df_train_full.isna().any()
# Out:
# GP         False
# MIN        False
# PTS        False
# FGM        False
# FGA        False
# FG%        False
# 3P Made    False
# 3PA        False
# 3P%        False
# FTM        False
# FTA        False
# FT%        False
# OREB       False
# DREB       False
# REB        False
# AST        False
# STL        False
# BLK        False
# TOV        False
# Target     False
# dtype: bool

# %%
# dropping some highly correlated features from datasets

df_train_full = df_train_full.drop(['FGM', 'FGA', '3PA', 'REB', 'MIN', 'FTM'], axis = 1)
df_test_full = df_test_full.drop(['FGM', 'FGA', '3PA', 'REB', 'MIN', 'FTM'], axis = 1)

plt.figure(figsize=(20, 20))
sns.heatmap(df_train_full.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# splitting training and validation sets

X_train_full = df_train_full.drop(['Target'], axis = 1)
y_train_full = df_train_full['Target']

X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size = 0.25, random_state = 0)

# %% [markdown]
# ## Normalizing The Data

# %%
y_train_full = y_train_full.values.reshape(-1,1)
y_train = y_train.values.reshape(-1,1)
y_valid = y_valid.values.reshape(-1,1)

# %%
# Normalization must be done with the mean and standard deviation of X_train only

X_train_full = (X_train_full - X_train_full.mean()) / (X_train_full.std())

mean = X_train_full.mean()
std = X_train_full.std()

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(n_estimators = 5000, random_state = 0)

# %%
# normalizing X_train, X_valid, df_test_full

X_train = (X_train - mean)/(std)
X_valid = (X_valid - mean)/ (std)
df_test_full = (df_test_full - mean) / (std)

# %%
xgb.fit(X_train, y_train, early_stopping_rounds = 15, eval_set = [(X_valid, y_valid)])
# Out:
# [0]	validation_0-logloss:0.64574
# [1]	validation_0-logloss:0.62019
# [2]	validation_0-logloss:0.60629
# [3]	validation_0-logloss:0.59468
# [4]	validation_0-logloss:0.59093
# [5]	validation_0-logloss:0.58680
# [6]	validation_0-logloss:0.58240
# [7]	validation_0-logloss:0.57656
# [8]	validation_0-logloss:0.57286
# [9]	validation_0-logloss:0.58501
# [10]	validation_0-logloss:0.58777
# [11]	validation_0-logloss:0.58570
# [12]	validation_0-logloss:0.58619
# [13]	validation_0-logloss:0.58455
# [14]	validation_0-logloss:0.58571
# [15]	validation_0-logloss:0.58719
# [16]	validation_0-logloss:0.58634
# [17]	validation_0-logloss:0.58893
# [18]	validation_0-logloss:0.59018
# [19]	validation_0-logloss:0.58693
# [20]	validation_0-logloss:0.59001
# [21]	validation_0-logloss:0.59002
# [22]	validation_0-logloss:0.58748
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=5000,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
from sklearn.metrics import accuracy_score
preds = xgb.predict(X_valid)
print(accuracy_score(y_valid, preds))
# Out:
# 0.7246376811594203

# %%
from sklearn.model_selection import cross_val_score

print(cross_val_score(xgb, X_train_full, y_train_full, cv = 4))
# Out:
# [0.71014493 0.70545455 0.68727273 0.71272727]

# %%
preds = xgb.predict(df_test_full)
print(preds.shape)
output = pd.DataFrame({'prediction':preds})
output.to_csv('submission2_xgboost.csv', index = False)
# Out:
# (555,)

# %% [markdown]
# # Naive Bayes Approach

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

# %%
y_pred = gnb.fit(X_train, y_train).predict(X_valid)

print(cross_val_score(gnb, X_train_full, y_train_full, cv = 5))
# Out:
# [0.67873303 0.69090909 0.67727273 0.66363636 0.67272727]

# %% [markdown]
# ## Doesn't seem to be a good approach here.

# %%
preds_N = gnb.predict(df_test_full)
print(preds_N.shape)
output = pd.DataFrame({'prediction':preds_N})
output.to_csv('submission3_naiveBayes.csv', index = False)
# Out:
# (555,)

# %% [markdown]
# ###  XGBOOST  GAVE SCORE OF 88% ON TEST DATA (SUBMISSION TO HACKATHON)
# ### GAUSSIAN NAIVE BAYES GAVE SCORE OF 72.5% ON TEST DATA (SUBMISSION TO HACKATHON)

# %%
sns.pairplot(X_train_full)

# %% [markdown]
# # Trying LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter = 1000)
logreg.fit(X_train, y_train)
print(accuracy_score(y_valid, logreg.predict(X_valid)))
print(cross_val_score(logreg, X_train_full, y_train_full, cv = 4))
# Out:
# 0.7101449275362319
# [0.70652174 0.66545455 0.70545455 0.70181818]

# %%
preds_l = logreg.predict(df_test_full)
print(preds_N.shape)
output = pd.DataFrame({'prediction':preds_l})
output.to_csv('submission_Log.csv', index = False)
# Out:
# (555,)

# %% [markdown]
# ### prediction score of logistic regression (71.8% on Test Data)
