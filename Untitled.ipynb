# %%
import pandas as pd

# %%
url = './../../../Downloads/MOCK_DATA.csv'
data = pd.read_csv(url)
data
# Out:
#        id first_name     last_name                         email  gender  \
# 0       1     Waylin        Duiged             wduiged0@yale.edu    Male
# 1       2       Romy     Dovington        rdovington1@sphinn.com  Female
# 2       3    Zachary      Blackney       zblackney2@mapquest.com    Male
# 3       4    Bastien    Eccleshall  beccleshall3@arstechnica.com    Male
# 4       5       Wynn         Wines               wwines4@mail.ru    Male
# ..    ...        ...           ...                           ...     ...
# 995   996     Jdavie        Dutton       jduttonrn@aboutads.info    Male
# 996   997       Dona  Tomankiewicz       dtomankiewiczro@mapy.cz  Female
# 997   998       Sven    Bottinelli      sbottinellirp@census.gov    Male
# 998   999    Charlot        Luckie            cluckierq@hibu.com  Female
# 999  1000      Milly        Clacey           mclaceyrr@state.gov  Female
#
#          ip_address
# 0      172.50.76.39
# 1      86.179.109.1
# 2    18.232.244.149
# ...
